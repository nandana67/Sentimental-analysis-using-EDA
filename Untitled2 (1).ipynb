# %%
import numpy as np
import pandas as pd
import keras
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import keras.models as km
from keras import activations,initializers,regularizers,constraints
from keras.layers import Dense, Activation

# %%
df=pd.read_csv("winequality-red.csv")

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  pH  sulphates
# 0                 11.0   3       0.56
# 1                 25.0   3       0.68
# 2                 15.0   3       0.65
# 3                 17.0   3       0.58
# 4                 11.0   3       0.56

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   fixed acidity        1599 non-null   float64
#  1   volatile acidity     1599 non-null   float64
#  2   citric acid          1599 non-null   float64
#  3   residual sugar       1599 non-null   float64
#  4   chlorides            1599 non-null   float64
#  5   free sulfur dioxide  1599 non-null   float64
#  6   pH                   1599 non-null   int64
#  7   sulphates            1599 non-null   float64
# dtypes: float64(7), int64(1)
# memory usage: 100.1 KB

# %%
pd.isnull(df).sum()
# Out:
# fixed acidity          0
# volatile acidity       0
# citric acid            0
# residual sugar         0
# chlorides              0
# free sulfur dioxide    0
# pH                     0
# sulphates              0
# dtype: int64

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'pH', 'sulphates'],
#       dtype='object')

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide           pH    sulphates
# count  1599.000000          1599.000000  1599.000000  1599.000000
# mean      0.087467            15.874922     2.983114     0.658149
# std       0.047065            10.460157     0.138253     0.169507
# min       0.012000             1.000000     2.000000     0.330000
# ...

# %%
import pandas as pd
import seaborn as sns

df=pd.read_csv("winequality-red.csv")
sales_gen=df.groupby(['fixed acidity'],as_index=False)['quality'].sum().sort_values(by='quality',ascending=False)
sns.barplot(x='fixed acidity',y='quality',data=sales_gen)
# Out:
# <Axes: xlabel='fixed acidity', ylabel='quality'>

# %%
df['fixed acidity']=df['fixed acidity'].astype('int')

# %%
ax=sns.countplot(x='fixed acidity',data=df)
sns.set(rc={'figure.figsize':(20,10)})
for bars in ax.containers:
  ax.bar_label(bars)

# %%
sales_gen=df.groupby(['quality'],as_index=False)['pH'].sum().sort_values(by='pH',ascending=False)
sns.barplot(y='pH',x='quality',data=sales_gen)
# Out:
# <Axes: xlabel='quality', ylabel='pH'>

# %%
sales_gen=df.groupby(['quality'],as_index=False)['chlorides'].sum().sort_values(by='chlorides',ascending=False)
sns.barplot(y='chlorides',x='quality',data=sales_gen)
# Out:
# <Axes: xlabel='quality', ylabel='chlorides'>

# %%
sales_gen=df.groupby(['quality'],as_index=False)['volatile acidity'].sum().sort_values(by='volatile acidity',ascending=False)
sns.barplot(y='volatile acidity',x='quality',data=sales_gen)
# Out:
# <Axes: xlabel='quality', ylabel='volatile acidity'>

# %%
sales_gen=df.groupby(['quality'],as_index=False)['free sulfur dioxide'].sum().sort_values(by='free sulfur dioxide',ascending=False)
sns.barplot(y='free sulfur dioxide',x='quality',data=sales_gen)
# Out:
# <Axes: xlabel='quality', ylabel='free sulfur dioxide'>

# %%
ax=sns.countplot(x='fixed acidity',data=df,hue='quality')
sns.set(rc={'figure.figsize':(20,5)})
for bars in ax.containers:
  ax.bar_label(bars)

# %%
df["quality"].value_counts()
# Out:
# quality
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: count, dtype: int64

# %%
X=df.drop(columns=['quality'])
y=df["quality"]

# %%
train_X,test_X,train_y,test_y=train_test_split(X,y,test_size=0.3,random_state=123)

# %%
train_X.shape
# Out:
# (1119, 11)

# %%
model=Sequential()
model.add(Dense(units=11,kernel_initializer='uniform',activation='relu',input_dim=11))
model.add(Dense(units=6,kernel_initializer='uniform',activation='relu'))
model.add(Dense(units=4,kernel_initializer='uniform',activation='relu'))
model.add(Dense(units=1,kernel_initializer='uniform',activation='linear'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0                 7             0.700         0.00             1.9      0.076
# 1                 7             0.880         0.00             2.6      0.098
# 2                 7             0.760         0.04             2.3      0.092
# 3                11             0.280         0.56             1.9      0.075
# 4                 7             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594              6             0.600         0.08             2.0      0.090
# 1595              5             0.550         0.10             2.2      0.062
# 1596              6             0.510         0.13             2.3      0.076
# 1597              5             0.645         0.12             2.0      0.075
# 1598              6             0.310         0.47             3.6      0.067
#
# ...

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 11)             │           132 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 6)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 4)              │            28 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 237 (948.00 B)
#  Trainable params: 237 (948.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
print(train_X.shape)
print(train_y.shape)
# Out:
# (1119, 11)
# (1119,)

# %%
model.fit(train_X,train_y,epochs=50,batch_size=32,validation_split=0.1)
mse=model.evaluate(test_X,test_y)
print(f"Test Mean Squared Error: {mse}")
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5568 - val_loss: 0.6064
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5017 - val_loss: 0.6041
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5378 - val_loss: 0.5930
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5701 - val_loss: 0.6121
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5360 - val_loss: 0.5920
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4958 - val_loss: 0.5860
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5981 - val_loss: 0.5887
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4784 - val_loss: 0.5776
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5136 - val_loss: 0.5778
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5047 - val_loss: 0.5746
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4977 - val_loss: 0.5782
# Epoch 12/50
# ...

# %%
predictions=model.predict(test_X)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
predictions
# Out:
# array([[6.3834095],
#        [4.96533  ],
#        [5.0174446],
#        [6.2168827],
#        [5.1914144],
#        [5.5446506],
#        [5.994491 ],
#        [5.5067983],
#        [5.481519 ],
#        [5.520739 ],
#        [4.950829 ],
#        [6.55726  ],
#        [5.609094 ],
#        [5.8907046],
#        [5.7831473],
#        [5.9505935],
#        [5.0454288],
#        [5.8648477],
#        [5.8531513],
#        [5.2399545],
#        [5.8581862],
#        [5.609094 ],
#        [5.6065974],
#        [5.2447343],
#        [5.2635612],
#        [5.2967315],
#        [5.680255 ],
#        [5.6307616],
#        [5.8793426],
#        [5.671137 ],
#        [4.9795737],
#        [6.2411113],
#        [5.313246 ],
#        [5.0468793],
#        [6.085312 ],
#        [4.9126744],
#        [5.467814 ],
#        [6.3845387],
#        [4.9205937],
#        [5.106374 ],
#        [5.447069 ],
#        [5.99952  ],
#        [5.812348 ],
#        [5.6179814],
#        [5.3705335],
# ...
